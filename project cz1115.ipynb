# %%
# Basic Libraries
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics
import json
import requests

# %%
r = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=f8321c17110659f4510b22d316bc1389&language=en-US")

# %%
r_json = r.json()

# %%
type(r_json)
# Out:
# dict

# %%
df = pd.DataFrame.from_dict(r_json)

# %%
df.head()
# Out:
#    page                                            results  total_pages  \
# 0     1  {'adult': False, 'backdrop_path': '/fQq1FWp1rC...          422
# 1     1  {'adult': False, 'backdrop_path': '/jtAI6OJIWL...          422
# 2     1  {'adult': False, 'backdrop_path': '/xRI636TOdS...          422
# 3     1  {'adult': False, 'backdrop_path': '/tXHpvlr5F7...          422
# 4     1  {'adult': False, 'backdrop_path': '/w2uGvCpMtv...          422
#
#    total_results
# 0           8430
# 1           8430
# 2           8430
# 3           8430
# 4           8430

# %%
a= r_json["results"]

# %%
df = pd.DataFrame.from_dict(a)

# %%
df.head()
# Out:
#    adult                     backdrop_path        genre_ids      id  \
# 0  False  /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg      [10749, 35]  761053
# 1  False  /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg          [10749]  724089
# 2  False  /xRI636TOdS1K1GBqIBRSmfZ1T5x.jpg  [35, 18, 10749]   19404
# 3  False  /tXHpvlr5F7gV5DwgS7M5HBrUi2C.jpg         [18, 80]     278
# 4  False  /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg          [10749]  696374
#
#   original_language                original_title  \
# 0                en    Gabriel's Inferno Part III
# 1                en     Gabriel's Inferno Part II
# 2                hi  दिलवाले दुल्हनिया ले जायेंगे
# 3                en      The Shawshank Redemption
# 4                en             Gabriel's Inferno
#
#                                             overview  popularity  \
# 0  The final part of the film adaption of the ero...      33.404
# 1  Professor Gabriel Emerson finally learns the t...       8.803
# 2  Raj is a rich, carefree, happy-go-lucky second...      14.487
# 3  Framed in the 1940s for the double murder of h...      45.606
# 4  An intriguing and sinful exploration of seduct...      12.163
#
#                         poster_path release_date                        title  \
# 0  /fYtHxTxlhzD4QWfEbrC1rypysSD.jpg   2020-11-19   Gabriel's Inferno Part III
# 1  /pci1ArYW7oJ2eyTo2NMYEKHHiCP.jpg   2020-07-31    Gabriel's Inferno Part II
# 2  /2CAL2433ZeIihfX1Hb2139CX0pW.jpg   1995-10-20  Dilwale Dulhania Le Jayenge
# 3  /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg   1994-09-23     The Shawshank Redemption
# 4  /oyG9TL7FcRP4EZ9Vid6uKzwdndz.jpg   2020-05-29            Gabriel's Inferno
#
#    video  vote_average  vote_count
# 0  False           8.9         719
# 1  False           8.8        1176
# 2  False           8.8        2656
# 3  False           8.7       18362
# 4  False           8.7        1944

# %%
title=df['title']

# %%
df2= pd.concat([title,df],axis=1)

# %%
df2
# Out:
#                                         title  adult  \
# 0                  Gabriel's Inferno Part III  False
# 1                   Gabriel's Inferno Part II  False
# 2                 Dilwale Dulhania Le Jayenge  False
# 3                    The Shawshank Redemption  False
# 4                           Gabriel's Inferno  False
# 5                                 Wolfwalkers  False
# 6                               The Godfather  False
# 7                            Schindler's List  False
# 8                                  Your Name.  False
# 9                      The Godfather: Part II  False
# 10                         Dedicated to my ex  False
# 11   Rascal Does Not Dream of a Dreaming Girl  False
# 12                              Spirited Away  False
# 13                                   Parasite  False
# 14  Miraculous World: New York, United HeroeZ  False
# 15                             The Green Mile  False
# 16                                     Clouds  False
# 17                                   Hamilton  False
# 18                               Pulp Fiction  False
# 19                          Life Is Beautiful  False
#
#                        backdrop_path                genre_ids      id  \
# 0   /fQq1FWp1rC89xDrRMuyFJdFUdMd.jpg              [10749, 35]  761053
# 1   /jtAI6OJIWLWiRItNSZoWjrsUtmi.jpg                  [10749]  724089
# 2   /xRI636TOdS1K1GBqIBRSmfZ1T5x.jpg          [35, 18, 10749]   19404
# 3   /tXHpvlr5F7gV5DwgS7M5HBrUi2C.jpg                 [18, 80]     278
# 4   /w2uGvCpMtvRqZg6waC1hvLyZoJa.jpg                  [10749]  696374
# 5   /mxn0RJ6stopje13MZdwU35XDnAx.jpg      [10751, 12, 16, 14]  441130
# 6   /7VrRna8S3x6xbijooeBmxqvHXiu.jpg                 [18, 80]     238
# 7   /loRmRzQXZeqG78TqZuyvSlEQfZb.jpg          [18, 36, 10752]     424
# 8   /dIWwZW7dJJtqC6CgWzYkNVKIUm8.jpg          [10749, 16, 18]  372058
# 9   /poec6RqOKY9iSiIUmfyfPfiLtvB.jpg                 [18, 80]     240
# 10  /1fOsyhVz5qyX2rl1qqX6KImVhTx.jpg                 [18, 35]  644479
# 11  /hQQTE285UQB1lLY1XiioQ77LYnC.jpg  [16, 35, 10749, 18, 14]  572154
# 12  /mSDsSDwaP3E7dEfUPWy4J0djt4O.jpg          [16, 10751, 14]     129
# 13   /TU9NIjwzjoKPwQHoHshkFcQUCG.jpg             [35, 53, 18]  496243
# 14  /yR27bZPIkNhpGEIP3jKV2EifTgo.jpg              [16, 10751]  755812
# 15  /xMIyotorUv2Yz7zpQz2QYc8wkWB.jpg             [14, 18, 80]     497
# 16  /bx326cwBtDsfDcnTgFlK5dXkyaC.jpg       [10402, 18, 10749]  630566
# 17  /uWVkEo9PWHu9algZsiLPi6sRU64.jpg          [36, 10402, 18]  556574
# 18  /w7RDIgQM6bLT7JXtH4iUQd3Iwxm.jpg                 [53, 80]     680
# 19  /6aNKD81RHR1DqUUa8kOZ1TBY1Lp.jpg                 [35, 18]     637
#
#    original_language                             original_title  \
# 0                 en                 Gabriel's Inferno Part III
# 1                 en                  Gabriel's Inferno Part II
# 2                 hi               दिलवाले दुल्हनिया ले जायेंगे
# 3                 en                   The Shawshank Redemption
# 4                 en                          Gabriel's Inferno
# 5                 en                                Wolfwalkers
# 6                 en                              The Godfather
# 7                 en                           Schindler's List
# 8                 ja                                      君の名は。
# 9                 en                     The Godfather: Part II
# 10                es                           Dedicada a mi ex
# 11                ja                        青春ブタ野郎はゆめみる少女の夢を見ない
# 12                ja                                   千と千尋の神隠し
# 13                ko                                        기생충
# 14                fr  Miraculous World: New York, United HeroeZ
# 15                en                             The Green Mile
# 16                en                                     Clouds
# 17                en                                   Hamilton
# 18                en                               Pulp Fiction
# 19                it                            La vita è bella
#
#                                              overview  popularity  \
# 0   The final part of the film adaption of the ero...      33.404
# 1   Professor Gabriel Emerson finally learns the t...       8.803
# 2   Raj is a rich, carefree, happy-go-lucky second...      14.487
# 3   Framed in the 1940s for the double murder of h...      45.606
# 4   An intriguing and sinful exploration of seduct...      12.163
# 5   In a time of superstition and magic, when wolv...      24.090
# 6   Spanning the years 1945 to 1955, a chronicle o...      41.762
# 7   The true story of how businessman Oskar Schind...      30.708
# 8   High schoolers Mitsuha and Taki are complete s...      99.676
# 9   In the continuing saga of the Corleone crime f...      29.775
# 10  The film tells the story of Ariel, a 21-year-o...      38.537
# 11  In Fujisawa, Sakuta Azusagawa is in his second...     126.330
# 12  A young girl, Chihiro, becomes trapped in a st...      45.851
# 13  All unemployed, Ki-taek's family takes peculia...     123.738
# 14  During a school field trip, Ladybug and Cat No...     545.457
# 15  A supernatural tale set on death row in a Sout...      35.184
# 16  Young musician Zach Sobiech discovers his canc...      29.742
# 17  Presenting the tale of American founding fathe...      19.724
# 18  A burger-loving hit man, his philosophical par...      76.057
# 19  A touching story of an Italian book seller of ...      28.500
#
#                          poster_path release_date  \
# 0   /fYtHxTxlhzD4QWfEbrC1rypysSD.jpg   2020-11-19
# 1   /pci1ArYW7oJ2eyTo2NMYEKHHiCP.jpg   2020-07-31
# 2   /2CAL2433ZeIihfX1Hb2139CX0pW.jpg   1995-10-20
# 3   /q6y0Go1tsGEsmtFryDOJo3dEmqu.jpg   1994-09-23
# 4   /oyG9TL7FcRP4EZ9Vid6uKzwdndz.jpg   2020-05-29
# 5   /ehAKuE48okTuonq6TpsNQj8vFTC.jpg   2020-10-26
# 6   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 7   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-11-30
# 8   /iaiy3tg9QVkDpObm1IGqmbC9A5C.jpg   2016-08-26
# 9   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 10  /riAooJrFvVhotyaOgoI0WR7okSe.jpg   2019-11-01
# 11  /7Ai8vNEv4zEveh12JViGikoVPVV.jpg   2019-06-15
# 12  /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20
# 13  /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30
# 14  /kIHgjAkuzvKBnmdstpBOo4AfZah.jpg   2020-09-26
# 15  /velWPhVMQeQKcxggNEU8YmIo52R.jpg   1999-12-10
# 16  /d0OdD1I8qAfETvE9Rp9Voq7R8LR.jpg   2020-10-09
# 17  /h1B7tW0t399VDjAcWJh8m87469b.jpg   2020-07-03
# 18  /plnlrtBUULT0rh3Xsjmpubiso3L.jpg   1994-09-10
# 19  /74hLDKjD5aGYOotO6esUVaeISa2.jpg   1997-12-20
#
#                                         title  video  vote_average  vote_count
# 0                  Gabriel's Inferno Part III  False           8.9         719
# 1                   Gabriel's Inferno Part II  False           8.8        1176
# 2                 Dilwale Dulhania Le Jayenge  False           8.8        2656
# 3                    The Shawshank Redemption  False           8.7       18362
# 4                           Gabriel's Inferno  False           8.7        1944
# 5                                 Wolfwalkers  False           8.7         253
# 6                               The Godfather  False           8.7       13860
# 7                            Schindler's List  False           8.6       11044
# 8                                  Your Name.  False           8.6        7118
# 9                      The Godfather: Part II  False           8.6        8275
# 10                         Dedicated to my ex  False           8.6         338
# 11   Rascal Does Not Dream of a Dreaming Girl  False           8.5         225
# 12                              Spirited Away  False           8.5       10951
# 13                                   Parasite  False           8.5       10732
# 14  Miraculous World: New York, United HeroeZ  False           8.5         414
# 15                             The Green Mile  False           8.5       11838
# 16                                     Clouds  False           8.5         619
# 17                                   Hamilton  False           8.5         631
# 18                               Pulp Fiction  False           8.5       20623
# 19                          Life Is Beautiful  False           8.5        9896

# %%
df.describe()
# Out:
#                   id  popularity  vote_average    vote_count
# count      20.000000   20.000000     20.000000     20.000000
# mean   333652.950000   70.479700      8.610000   6583.700000
# std    321425.173392  116.948499      0.125237   6552.879778
# min       129.000000    8.803000      8.500000    225.000000
# 25%       478.750000   27.397500      8.500000    628.000000
# 50%    406594.000000   34.294000      8.600000   4887.000000
# 75%    634044.250000   53.402500      8.700000  10974.250000
# max    761053.000000  545.457000      8.900000  20623.000000
